# %%
import os
#file_path = os.path.join(os.getcwd(), "data", "world_countries.csv")

file_path = 'C:/Users/Tarek/Documents/Anaconda/data/all.csv'

import pandas as pd

data = pd.read_csv(file_path, encoding = 'iso-8859-1')


import base64
import pandas as pd
from IPython.display import HTML

# %%
data.dtypes
# Out:
# _id:string           float64
# acl:object           float64
# _createdAt:date      float64
# _updatedAt:date      float64
# item:string           object
# Definition:string     object
# dtype: object

# %%
data
# Out:
#      _id:string  acl:object  _createdAt:date  _updatedAt:date  \
# 0           NaN         NaN              NaN              NaN
# 1           NaN         NaN              NaN              NaN
# 2           NaN         NaN              NaN              NaN
# 3           NaN         NaN              NaN              NaN
# 4           NaN         NaN              NaN              NaN
# 5           NaN         NaN              NaN              NaN
# 6           NaN         NaN              NaN              NaN
# 7           NaN         NaN              NaN              NaN
# 8           NaN         NaN              NaN              NaN
# 9           NaN         NaN              NaN              NaN
# 10          NaN         NaN              NaN              NaN
# 11          NaN         NaN              NaN              NaN
# 12          NaN         NaN              NaN              NaN
# 13          NaN         NaN              NaN              NaN
# ...

# %%
data["Definition:string"]=data["Definition:string"].apply(lambda x:str(x).replace("\n",""))

# %%
data["item:string"]=data["item:string"].apply(lambda x:str(x).replace("\n",""))

# %%
data["item:string"]=data["item:string"].apply(lambda x:str(x).capitalize())

# %%
data["Definition:string"]=data["Definition:string"].apply(lambda x:str(x).capitalize())

# %%
data["Definition:string"]=data["Definition:string"].apply(lambda x:str(x).strip())

# %%
data["item:string"]=data["item:string"].apply(lambda x:str(x).strip())

# %%
data
# Out:
#      _id:string  acl:object  _createdAt:date  _updatedAt:date  \
# 0           NaN         NaN              NaN              NaN
# 1           NaN         NaN              NaN              NaN
# 2           NaN         NaN              NaN              NaN
# 3           NaN         NaN              NaN              NaN
# 4           NaN         NaN              NaN              NaN
# 5           NaN         NaN              NaN              NaN
# 6           NaN         NaN              NaN              NaN
# 7           NaN         NaN              NaN              NaN
# 8           NaN         NaN              NaN              NaN
# 9           NaN         NaN              NaN              NaN
# 10          NaN         NaN              NaN              NaN
# 11          NaN         NaN              NaN              NaN
# 12          NaN         NaN              NaN              NaN
# 13          NaN         NaN              NaN              NaN
# ...

# %%
def create_download_link( df, title = "Download CSV file", filename = "data.csv"):
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(data)
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
